# %%
from astropy.io import fits
from pathlib import Path
import matplotlib.pyplot as plt

from xhcd.core import Spectrum

fe_data = Spectrum("Z:\Astro_BlackCAT\BlackCAT_Calibration_Data\LC_Calibration_Data\y2024-12-11\BC028_Al_LP_233K_HORI_0_0\Analysis\imaging_analysis_20241213\combined_events_th1_200.fits.gz", th1=200, th2=50, graded=False)
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\A'
# <>:7: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\ajo5182\AppData\Local\Temp\ipykernel_56216\2025567306.py:7: SyntaxWarning: invalid escape sequence '\A'
#   fe_data = Spectrum("Z:\Astro_BlackCAT\BlackCAT_Calibration_Data\LC_Calibration_Data\y2024-12-11\BC028_Al_LP_233K_HORI_0_0\Analysis\imaging_analysis_20241213\combined_events_th1_200.fits.gz", th1=200, th2=50, graded=False)

# %%
data_path = Path("Z:\Astro_BlackCAT\BlackCAT_Calibration_Data\LC_Calibration_Data\y2024-12-13\BC078_Fe_FF_243K_GRID_N10_N10\Analysis\imaging_analysis_20241213\combined_events_th1_200.fits.gz")

d = fits.open(data_path) # open fits file
        
data = d[1].data # data contents of the fits file
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\ajo5182\AppData\Local\Temp\ipykernel_56216\4027516498.py:1: SyntaxWarning: invalid escape sequence '\A'
#   data_path = Path("Z:\Astro_BlackCAT\BlackCAT_Calibration_Data\LC_Calibration_Data\y2024-12-13\BC078_Fe_FF_243K_GRID_N10_N10\Analysis\imaging_analysis_20241213\combined_events_th1_200.fits.gz")

# %%
plt.figure(figsize=(10,8))
pix_counts = fe_data.plotPixelCounts(vmax=4, show=False)
plt.colorbar()
plt.show()
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
d
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x0000023245C45D30>, <astropy.io.fits.hdu.table.BinTableHDU object at 0x00000232462181D0>]
